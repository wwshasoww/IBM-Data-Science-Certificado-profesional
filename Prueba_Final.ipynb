# %%
import requests

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-AI0271EN-SkillsNetwork/labs/v1/m3/data/used_car_price_analysis.csv"
response = requests.get(url)
open("used_car_price_analysis.csv", "wb").write(response.content)
print("Archivo descargado correctamente.")
# Out:
# Archivo descargado correctamente.

# %%
import pandas as pd

file_path = "dataset (1).csv"
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %%
df = pd.read_csv("dataset (1).csv")
cols_with_missing = df.columns[df.isnull().any()]
df[cols_with_missing] = df[cols_with_missing].fillna(df.mean(numeric_only=True))
df = df.drop_duplicates()
print(df.head())
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %%
df = pd.read_csv("dataset (1).csv")
correlations = df.corr(numeric_only=True)["Price"].abs().sort_values(ascending=False)
top5 = correlations.index[1:6]
print(top5)
# Out:
# Index(['RAM_GB', 'CPU_core', 'CPU_frequency', 'Unnamed: 0', 'GPU'], dtype='object')
